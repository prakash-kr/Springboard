# %% [markdown]
# # Hateful Meme Challenge

# %%
from PIL import Image
import os, sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = 'data/train.jsonl'
df = pd.read_json(filepath, lines=True)

# %%
df.head()
# Out:
#       id            img  label  \
# 0  42953  img/42953.png      0
# 1  23058  img/23058.png      0
# 2  13894  img/13894.png      0
# 3  37408  img/37408.png      0
# 4  82403  img/82403.png      0
#
#                                                 text
# 0   its their character not their color that matters
# 1  don't be afraid to love again everyone is not ...
# 2                           putting bows on your pet
# 3  i love everything and everybody! except for sq...
# 4  everybody loves chocolate chip cookies, even h...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8500 entries, 0 to 8499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8500 non-null   int64
#  1   img     8500 non-null   object
#  2   label   8500 non-null   int64
#  3   text    8500 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 265.8+ KB

# %%
path = "data/img/"
dirs = os.listdir( path )
dirs
# Out:
# ['01235.png',
#  '01236.png',
#  '01243.png',
#  '01245.png',
#  '01247.png',
#  '01256.png',
#  '01258.png',
#  '01264.png',
#  '01268.png',
#  '01269.png',
#  '01274.png',
#  '01275.png',
#  '01276.png',
#  '01278.png',
#  '01284.png',
#  '01285.png',
#  '01293.png',
#  '01295.png',
#  '01324.png',
#  '01325.png',
#  '01327.png',
#  '01329.png',
#  '01348.png',
#  '01349.png',
#  '01358.png',
#  '01359.png',
#  '01364.png',
#  '01368.png',
#  '01379.png',
#  '01382.png',
#  '01389.png',
#  '01392.png',
#  '01395.png',
#  '01397.png',
#  '01423.png',
#  '01425.png',
#  '01436.png',
#  '01439.png',
#  '01452.png',
#  '01456.png',
#  '01459.png',
#  '01465.png',
#  '01467.png',
#  '01468.png',
#  '01469.png',
#  '01472.png',
#  '01475.png',
#  '01476.png',
#  '01483.png',
#  '01487.png',
#  '01492.png',
#  '01497.png',
#  '01498.png',
#  '01524.png',
#  '01526.png',
#  '01527.png',
#  '01529.png',
#  '01546.png',
#  '01547.png',
#  '01548.png',
#  '01562.png',
#  '01564.png',
# ...

# %%
len(dirs)
# Out:
# 12140

# %%
type(dirs)
# Out:
# list

# %%
res = [sub.replace('.png', '') for sub in dirs]

# %%
res
# Out:
# ['01235',
#  '01236',
#  '01243',
#  '01245',
#  '01247',
#  '01256',
#  '01258',
#  '01264',
#  '01268',
#  '01269',
#  '01274',
#  '01275',
#  '01276',
#  '01278',
#  '01284',
#  '01285',
#  '01293',
#  '01295',
#  '01324',
#  '01325',
#  '01327',
#  '01329',
#  '01348',
#  '01349',
#  '01358',
#  '01359',
#  '01364',
#  '01368',
#  '01379',
#  '01382',
#  '01389',
#  '01392',
#  '01395',
#  '01397',
#  '01423',
#  '01425',
#  '01436',
#  '01439',
#  '01452',
#  '01456',
#  '01459',
#  '01465',
#  '01467',
#  '01468',
#  '01469',
#  '01472',
#  '01475',
#  '01476',
#  '01483',
#  '01487',
#  '01492',
#  '01497',
#  '01498',
#  '01524',
#  '01526',
#  '01527',
#  '01529',
#  '01546',
#  '01547',
#  '01548',
#  '01562',
#  '01564',
#  '01567',
#  '01568',
#  '01569',
#  '01576',
#  '01578',
#  '01579',
#  '01589',
#  '01594',
#  '01598',
#  '01627',
#  '01634',
#  '01637',
#  '01642',
#  '01643',
#  '01649',
#  '01653',
#  '01658',
#  '01672',
#  '01674',
#  '01682',
#  '01689',
# ...

# %%
imgs = df['img']

# %%
imgs = [sub.replace('.png', '') for sub in imgs]
imgs = [sub.replace('img/', '') for sub in imgs]
imgs
# Out:
# ['42953',
#  '23058',
#  '13894',
#  '37408',
#  '82403',
#  '16952',
#  '76932',
#  '70914',
#  '02973',
#  '58306',
#  '79351',
#  '34096',
#  '25489',
#  '19324',
#  '79346',
#  '13426',
#  '97628',
#  '14238',
#  '28936',
#  '59784',
#  '02146',
#  '70146',
#  '28061',
#  '97180',
#  '49752',
#  '25610',
#  '15872',
#  '72640',
#  '64318',
#  '17956',
#  '93547',
#  '10743',
#  '37091',
#  '25719',
#  '76825',
#  '72598',
#  '43078',
#  '51846',
#  '01569',
#  '95812',
#  '06418',
#  '53976',
#  '70193',
#  '60427',
#  '78395',
#  '04876',
#  '92075',
#  '86354',
#  '74386',
#  '59613',
#  '10263',
#  '48279',
#  '52610',
#  '58371',
#  '27401',
#  '89574',
#  '25473',
#  '47913',
#  '08295',
#  '02497',
#  '90471',
#  '69357',
#  '54602',
#  '15320',
#  '63182',
#  '20619',
#  '82457',
#  '81059',
#  '42137',
#  '74530',
#  '40832',
#  '46127',
#  '87594',
#  '12548',
#  '12894',
#  '02476',
#  '06937',
#  '05762',
#  '40259',
#  '85072',
#  '46537',
#  '56432',
#  '39805',
# ...

# %%
set(imgs).issubset(res)
# Out:
# True

# %% [markdown]
# so all our images exist

# %%
from wordcloud import WordCloud, STOPWORDS 
unique_string=(" ").join(df['text'])
wordcloud = WordCloud(width = 1000, height = 500).generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("text"+".png", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Generating a simple word cloud gives a hint that most of the comments are hatefully targeted over religion, color and gender.
